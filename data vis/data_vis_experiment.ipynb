# %%
import pandas as pd
import plotly.express as px
import plotly.graph_objs as go
from plotly.subplots import make_subplots

# %%
df = pd.read_csv('../fiel8_12days_time_series.csv')
df = df.rename(columns={"Unnamed: 0": "date"})
df.info()
# Out:
# <class 'pandas.core.frame.DataFrame'>
# RangeIndex: 85 entries, 0 to 84
# Data columns (total 12 columns):
#  #   Column     Non-Null Count  Dtype
# ---  ------     --------------  -----
#  0   date       85 non-null     object
#  1   gdd        85 non-null     float64
#  2   pmm        85 non-null     float64
#  3   tmax       85 non-null     float64
#  4   tmean      85 non-null     float64
#  5   tmin       85 non-null     float64
#  6   ndvi       47 non-null     float64
#  7   ndwi       47 non-null     float64
#  8   reci       47 non-null     float64
#  9   elevation  85 non-null     float64
#  10  exposure   85 non-null     float64
#  11  slope      85 non-null     float64
# dtypes: float64(11), object(1)
# memory usage: 8.1+ KB

# %%
# Create figure with secondary y-axis
fig = make_subplots(specs=[[{"secondary_y": True}]])
fig.add_trace(go.Scatter(
        name='Temperature',
        x=df['date'],
        y=df['tmean'],
        mode='lines',
        line=dict(color='rgb(31, 119, 180)'),
    ))
fig.add_trace(go.Scatter(
        name='Tmax',
        x=df['date'],
        y=df['tmean']+df['tmax'],
        mode='lines',
        marker=dict(color="#444"),
        line=dict(width=0),
        showlegend=False)
    )
fig.add_trace(go.Scatter(
        name='Tmin',
        x=df['date'],
        y=df['tmean']-df['tmin'],
        marker=dict(color="#444"),
        line=dict(width=0),
        mode='lines',
        fillcolor='rgba(68, 68, 68, 0.3)',
        fill='tonexty',
        showlegend=False
    ))
fig.add_trace(
    go.Bar(x=df['date'], y=df['pmm'], name="precipitation"),
    secondary_y=True,
)
fig.update_layout(
    template='ggplot2',
    yaxis_title='Temperature',
    title='Continuous, variable value error bars',
    hovermode="x"
)
fig.show()

# %%
fig = make_subplots(specs=[[{"secondary_y": True}]])
fig.add_trace(go.Scatter(
        name='NDVI',
        x=df['date'],
        y=df['ndvi'],
        mode='lines',
        line=dict(color='rgb(31, 119, 180)'),
    ))
fig.add_trace(go.Scatter(
        name='NDWI',
        x=df['date'],
        y=df['ndwi'],
        mode='lines',
        line=dict(color='rgb(90, 200, 70)'),
    ))
fig.update_layout(
    template='ggplot2')

# %%
fig = px.density_heatmap(df, x="ndvi", y="ndwi", marginal_x="box", marginal_y="box")
fig.update_layout(
    template='ggplot2')
fig.show()

# %%
df['TMA'] = df['tmean'].rolling(window=5,center=True).mean()
fig = make_subplots(specs=[[{"secondary_y": True}]])
fig.add_trace(go.Scatter(
        name='NDVI',
        x=df['date'],
        y=df['TMA'],
        mode='lines',
        line=dict(color='rgb(31, 119, 180)'),
    ))
fig.add_trace(go.Scatter(
        name='NDWI',
        x=df['date'],
        y=df['tmean'],
        mode='lines',
        line=dict(color='rgb(90, 200, 70)'),
    ))
fig.update_layout(
    template='ggplot2')
